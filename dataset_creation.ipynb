# %% [markdown]
# # Импорт
#
# События в блоке кода:
#
# - Импорт необходимых модулей
# - Загрузка необработанных датасетов

# %%
import re

import pandas as pd

from rdkit import Chem, DataStructs
from rdkit.Chem import Draw, Descriptors, AllChem, rdMolDescriptors
import rdkit.Chem.AllChem as AllChem

# %%
reaxys = pd.read_csv('reaxys.csv', sep='\t')
chembl = pd.read_csv('chembl.csv', sep='\t')
excape = pd.read_csv('excape.csv', sep=',')

# %%
reaxys
# Out:
#        Unnamed: 0                                             SMILES  \
# 0               0  COC1=C2C(=O)C3=C(C(O)=C4C[C@](O)(C[C@H](O[C@H]...
# 1               1  COC1=C2C(=O)C3=C(C(O)=C4C[C@](O)(C[C@H](O[C@H]...
# 2               2  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...
# 3               3  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...
# 4               4  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...
# ...           ...                                                ...
# 26431       21216  CC1=CC(F)=C(C=C1)C1=CN([C@@H]2CC[C@H](N)CC2)C2...
# 26432       21217  CC1=CC(F)=C(C=C1)C1=CN([C@@H]2CC[C@H](N)CC2)C2...
# 26433       21218  CC1=CC(F)=C(C=C1)C1=CN([C@@H]2CC[C@H](N)CC2)C2...
# 26434       21219  CC1=CC(F)=C(C=C1)C1=CN([C@@H]2CC[C@H](N)CC2)C2...
# 26435       21220  CC1=CC(F)=C(C=C1)C1=CN([C@@H]2CC[C@H](N)CC2)C2...
#
#                                              Target Name  \
# 0                      Cyclin-dependent kinase 7 [human]
# ...

# %%
chembl
# Out:
#       Unnamed: 0 Molecule ChEMBL ID  \
# 0              0       CHEMBL220946
# 1              1       CHEMBL374940
# 2              2       CHEMBL220258
# 3              3       CHEMBL221428
# 4              4      CHEMBL1940980
# ...          ...                ...
# 2824         681      CHEMBL4855877
# 2825         682      CHEMBL4778367
# 2826         683      CHEMBL4850615
# 2827         684      CHEMBL4754873
# 2828         685      CHEMBL4862643
#
#                                                  Smiles Standard Type  \
# 0     c1cn(-c2ccc3c(-c4cc5cc(CN6CCCCC6)ccc5[nH]4)n[n...          IC50
# 1     CN(C)C(=O)c1ccc2c(-c3cc4cc(CN5CCOCC5)ccc4[nH]3...          IC50
# 2     c1cnn(-c2ccc3c(-c4cc5cc(CN6CCCCC6)ccc5[nH]4)n[...          IC50
# 3     c1cc2[nH]c(-c3n[nH]c4cc(-c5cn[nH]c5)ccc34)cc2c...          IC50
# 4     C[C@H]1COc2c(NCCCn3cccn3)c(F)c(N)c3c(=O)c(C(=O...    Inhibition
# ...                                                 ...           ...
# ...

# %%
excape
# Out:
#      Unnamed: 0                                             SMILES  \
# 0         46207  C=12C(=NC=NC1C=C(C(=C2)OCCOC)OCCOC)NC=3C=C(C#C...
# 1        304753  O=S(=O)(N1CCN(CC1)C2=CC=NC(NC=3SC(C=4C=C(C=NC4...
# 2        318327              ClC1=NC(N)=CC(C=2C=3C(NC2)=NC=CC3)=C1
# 3        367206     O=C1NC=2C(NC1CC(=O)NC3=CC=C(N(C)C)C=C3)=CC=CC2
# 4        400303  S1C=2C(C(C=3C=CC(NC(=O)NC4=CC=C(OC)C=C4)=CC3)=...
# ..          ...                                                ...
# 509    68765275  BrC1=CC(S(=O)(=O)NC2=CC3=C(C4=C(C3=NO)C=CC=C4)...
# 510    69090547  ClC=1C(=NC(NC2=CN(N=C2)C)=NC1)NC3=C(C(=O)N)C=C...
# 511    69186761  C=1(C=CC=C(C1C=2C=3C=C(C=CC3C4=C(CN2)C=NC(=N4)...
# 512    69201363  FC(F)(F)CCC=1N=C(N=C2NC=CC21)NC3=CC=C(C=C3)C(=...
# 513    70769547  FC=1C=CC(C(=O)NC=2C=C(C3NC=4C(C5C3CC=C5)=C6C(=...
#
#     Activity_Flag
# 0               A
# 1               A
# 2               A
# 3               A
# 4               A
# ..            ...
# 509             A
# ...

# %% [markdown]
# # Мишень
#
# События в блоке кода:
#
# - Отбор только тех строк, которые содержат данные исключительно по СDK7 (вне зависимости от организма)

# %%
reaxys_unique_targets = reaxys['Target Name'].unique()

for r in reaxys_unique_targets:
    print(r)
# Out:
# Cyclin-dependent kinase 7 [human]
# G1/S-specific cyclin-D3 [human];+Cyclin-dependent kinase 7 [human]
# Cyclin-H [human];+CDK-activating kinase assembly factor MAT1 [human];+Cyclin-dependent kinase 7 [human]
# Cyclin-dependent kinase 7
# Cyclin-dependent kinase 7 [human];+Cyclin [human];+Cyclin-dependent kinase 7 [human];+Cyclin [human]
# Cyclin-dependent kinase 7;+Cyclin-H;+CDK-activating kinase assembly factor MAT1
# Cyclin-dependent kinase 7;+Cyclin-H
# G1/S-specific cyclin-D3;+Cyclin-dependent kinase 7
# Mating-type protein MAT-1;+Cytochrome c-type biogenesis protein CycH;+Cyclin-dependent kinase 7
# Cyclin-dependent kinase 7;+Cyclin;+Cyclin-dependent kinase 7;+Cyclin
# Cyclin-dependent kinase 7 [Candida albicans]
# Cyclin-dependent kinase 5 activator 1; CDK-activating kinase assembly factor MAT1
# CDK-activating kinase assembly factor MAT1
# Cyclin-dependent kinase 7 [human];+cyclin H [human]
# Cyclin-H;+Cyclin-dependent kinase 7
# ...

# %%
print(chembl['Target Name'].unique())
# Out:
# ['Cyclin-dependent kinase 7' 'CDK7/Cyclin H/MNAT1'
#  'Cyclin-dependent kinase' 'Protein cereblon/Cyclin-dependent kinase 7'
#  'Cyclin-dependent kinase 7/ cyclin H']

# %%
chembl_targets = ['Cyclin-dependent kinase 7', 'CDK7/Cyclin H/MNAT1',
                  'Cyclin-dependent kinase 7/ cyclin H']
chembl_target = chembl[chembl['Target Name'].isin(chembl_targets)]

# %%
reaxys_targets = ['Cyclin-dependent kinase 7 [human]', 'Cyclin-dependent kinase 7',
                  'Cyclin-dependent kinase 7 [Candida albicans]',
                  'Cyclin-dependent kinase 7; DDK kinase regulatory subunit DBF4',
                  'Cell division control protein 7 [human]; G2/mitotic-specific cyclin-B1 [human]',
                  'Acetyltransferase MAT1 [human];+Cyclin-H [human];+Cyclin-dependent kinase 7 [human]',
                  'Cell division cycle 7-related protein kinase [human];+Cyclin-B1-1 [human]',
                  'Cyclin-dependent kinase 7; CDK-activating kinase assembly factor MAT1; Cyclin-H',
                  'Cyclin-dependent kinase 7 [human]; Cyclin-H [human];+CDK-activating kinase assembly factor MAT1 [human]',
                  'cyclin H [human];+Cyclin-dependent kinase 7 [human]', 'CDK7/cycH', 'CDK/Cyclin (CDK7)',
                  'CDK/Cyclin (CDK7);+Cyclin-H', 'CDK7/cyclinH/MAT1',
                  'Cyclin-dependent kinase 7 [human]; Cyclin-H;+CDK-activating kinase assembly factor MAT1',
                  'CDK-activating kinase assembly factor MAT1;+Cyclin-H;+Cyclin-dependent kinase 7',
                  'CDK-activating kinase assembly factor MAT1;+Cyclin-dependent kinase 7; Cyclin-H',
                  'Cyclin-dependent kinase 7; Apoptosis regulator, Bcl-2;+Bcl-2-like protein 1 (isoform Bcl-X(L))',
                  'CDK-activating kinase assembly factor MAT1;+Cyclin-dependent kinase 7; Probable cyclin-H',
                  'Cyclin-dependent kinase 7;+Cyclin homolog',
                  'CDK-activating kinase assembly factor MAT1 [human];+Cytochrome c-type biogenesis protein CycH [human];+Cyclin-dependent kinase 7 [human]',
                  'Cyclin-H;+Maturase-like protein 1;+Cyclin-dependent kinase 7',
                  'Cyclin-H [human];+S-adenosylmethionine synthase 1 [human]; Cyclin-dependent kinase 7 [human]',
                  'Cyclin-H [human];+MATE efflux family protein 1 [human];+Cyclin-dependent kinase 7 [human]',
                  'Cyclin-H [human];+Cyclin-dependent kinase 7', 'CDK7/CycH/MAT1', 
                  'Cyclin-H [human];+CDK-activating kinase assembly factor MAT1 [human]; Cyclin-dependent kinase 7 [human]',
                  'CDK-activating kinase assembly factor MAT1;+Cyclin-H1-1;+Cyclin-dependent kinase 7',
                  'Cyclin-H1-1 [human];+Cyclin-dependent kinase 7 [human]',
                  'Cyclin-dependent kinase 7 [human];+CDK7/Cyclin (Cyclin E) [human]', 
                  'CDK7/cyclinH/MAT1 (Cyclin H) [human]', 
                  'Cyclin-dependent kinase 7;+Cyclin-H;+Cyclin-dependent kinase 7;+Cyclin-H', 'CDK7/CycH/MAT1' ,
                  'Cyclin-dependent kinase 7; Cyclin-H1-1',
                  'Cyclin-H [human];+Mating-type protein MAT-1 [human];+Cyclin-dependent kinase 7 [human]',
                  'Cyclin-H; CDK-activating kinase assembly factor MAT1;+Cyclin-dependent kinase 7',
                  'Cyclin-dependent kinase 7 [human];+CDK-activating kinase assembly factor MAT1 [human];+Cyclin-H [human]',
                  'Cyclin-dependent kinase 7 [human]; Cyclin-H [human]',
                  'Cyclin-dependent kinase 7;+CDK-activating kinase assembly factor MAT1;+Cyclin-H1-1',
                  'Cyclin-H;+Mating-type protein MAT-1;+Cyclin-dependent kinase 7',
                  'Cyclin-H;+CDK7/Cyclin (MAT)',
                  'Cyclin-H; Cyclin-dependent kinase 7; CDK-activating kinase assembly factor MAT1',
                  'CDK-activating kinase assembly factor MAT1;+Cyclin-dependent kinase 7',
                  'Cyclin-H;+CDK-activating kinase assembly factor MAT1; Cyclin-dependent kinase 7'
                  'Cyclin-dependent kinase 7;+Cyclin;+Cyclin-dependent kinase 7;+Cyclin;+Cyclin-dependent kinase 7;+Cyclin;+Cyclin-dependent kinase 7;+Cyclin',
                  'Cyclin-dependent kinase 7 [human];+Cyclin-H [human];+CDK-activating kinase assembly factor MAT1 [human]',
                  'Cyclin-dependent kinase 7 [human];+Cyclin-H [human]', 'Cyclin-H; Cyclin-dependent kinase 7',
                  'CDK-activating kinase assembly factor MAT1;+Cyclin-K; Cell division cycle 7-related protein kinase',
                  'CDK-activating kinase assembly factor MAT1;+Cytochrome c-type biogenesis protein CycH;+Cyclin-dependent kinase 7',
                  'Cyclin-dependent kinase 7 [human];+cyclin H [human]', 
                  'Cyclin-H;+Cyclin-dependent kinase 7',
                  'Cyclin-H [human];+Cyclin-dependent kinase 7 [human]',
                  'Cyclin-H;+CDK-activating kinase assembly factor MAT1;+Cyclin-dependent kinase 7',
                  'Cyclin-dependent kinase 7; Cyclin-H',
                  'Cyclin-dependent kinase 7;+Cyclin;+Cyclin-dependent kinase 7;+Cyclin',
                  'Cyclin-dependent kinase 7 [human]',
                  'G1/S-specific cyclin-D3 [human];+Cyclin-dependent kinase 7 [human]',
                  'Cyclin-H [human];+CDK-activating kinase assembly factor MAT1 [human];+Cyclin-dependent kinase 7 [human]',
                  'Cyclin-dependent kinase 7',
                  'Cyclin-dependent kinase 7 [human];+Cyclin [human];+Cyclin-dependent kinase 7 [human];+Cyclin [human]',
                  'Cyclin-dependent kinase 7;+Cyclin-H;+CDK-activating kinase assembly factor MAT1',
                  'Cyclin-dependent kinase 7;+Cyclin-H',
                  'G1/S-specific cyclin-D3;+Cyclin-dependent kinase 7'
                 ]
reaxys_target = reaxys.loc[reaxys['Target Name'].isin(reaxys_targets)]

# %% [markdown]
# # Параметр
#
# События в блоке кода:
#
# - Отбор измеренных для соединения параметров
#
# Что это за параметры?
#
# - **IC50** - концентрация полумаксимального ингибирования (чем ниже, тем активнее)
# - **EC50** - концентрацию лиганда, которая вызывает эффект, равный половине максимального возможного для данного лиганда (чем ниже, тем активнее)
# - **pIC50** - отрицательный логарифм IC50

# %%
chembl_target['Standard Type'].unique()
# Out:
# array(['IC50', 'Inhibition', 'Kd', 'Ki', 'Activity', 'Occ50', 'Ratio',
#        '% Control', '% Ctrl', 'Kinact', 'EC50',
#        '% Residual activity with Skepinone-L',
#        '% residual kinase activity', 'Residual Activity',
#        'Residual activity', 'Ki(app)'], dtype=object)

# %%
reaxys_target['Medchem: Measurement Parameter'].unique()
# Out:
# array(['IC50', 'inhibition percentage', 'inhibition rate',
#        'Kd (dissociation constant)', 'pKi', 'pIC50',
#        'Ki (inhibition constant)', 'control percentage', 'EC50'],
#       dtype=object)

# %%
chembl_IC50 = chembl_target[chembl_target['Standard Type'] == 'IC50']
chembl_EC50 = chembl_target[chembl_target['Standard Type'] == 'EC50']
chembl_type = pd.concat([chembl_IC50, chembl_EC50], axis=0)

# %%
reaxys_IC50 = reaxys_target[reaxys_target['Medchem: Measurement Parameter'] == 'IC50']
reaxys_EC50 = reaxys_target[reaxys_target['Medchem: Measurement Parameter'] == 'EC50']
reaxys_pIC50 = reaxys_target[reaxys_target['Medchem: Measurement Parameter'] == 'pIC50']
reaxys_type = pd.concat([reaxys_IC50, reaxys_EC50, reaxys_pIC50], axis=0)

# %% [markdown]
# # Единицы
#
# События в блоке кода:
#
# - Конвертация концентраций в наномолярную (по возможности)
# - Трансформация pIC50 в IC50

# %%
chembl_type['Standard Units'].value_counts()
# Out:
# nM    976
# Name: Standard Units, dtype: int64

# %%
reaxys_type['Unit'].value_counts()
# Out:
# nM         1854
# μM          893
# no unit     444
# µM          203
# M            17
# μmol/l        6
# mol/l         2
# nmol/l        1
# Name: Unit, dtype: int64

# %%
chembl_type_nan = chembl_type[chembl_type['Standard Units'].notna()]
reaxys_type_nan = reaxys_type[reaxys_type['Unit'].notna()]

# %%
lower_vals = []
upper_vals = []

for value in reaxys_type_nan['Quantitative value'].values:
    value_listed = list(value.split())
    if len(value_listed) > 1:
        if value_listed[0] < value_listed[2]:
            lower_val = value_listed[0]
            upper_val = value_listed[2]
            lower_vals.append(lower_val)
            upper_vals.append(upper_val)
        elif value_listed[0] > value_listed[2]:
            lower_val = value_listed[2]
            upper_val = value_listed[0]
            lower_vals.append(lower_val)
            upper_vals.append(upper_val)
        elif value_listed[0] == value_listed[2]:
            lower_val = value_listed[2]
            upper_val = value_listed[0]
            lower_vals.append(lower_val)
            upper_vals.append(upper_val)
    else:
        lower_vals.append(value_listed)
        upper_vals.append(value_listed)

# %%
lower_vals = [float(re.sub("[^0-9.]", "", str(i))) for i in lower_vals]
upper_vals = [float(re.sub("[^0-9.]", "", str(i))) for i in upper_vals]

# %%
reaxys_type_nan
# Out:
#        Unnamed: 0                                             SMILES  \
# 0               0  COC1=C2C(=O)C3=C(C(O)=C4C[C@](O)(C[C@H](O[C@H]...
# 1               1  COC1=C2C(=O)C3=C(C(O)=C4C[C@](O)(C[C@H](O[C@H]...
# 2               2  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...
# 3               3  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...
# 4               4  NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...
# ...           ...                                                ...
# 25247       20032  [H][C@]12C[C@@]1([H])C1=C(CN2C(=O)C2CCN(C)CC2C...
# 25248       20033  [H][C@]12C[C@@]1([H])C1=C(CN2C(=O)C2CCN(C)CC2C...
# 25249       20034  C[C@@H]1CC2=C(CN1C(=O)N1CCN(C)C[C@@H]1C1=CC=CC...
# 25250       20035  C[C@@H]1CC2=C(CN1C(=O)N1CCN(C)C[C@@H]1C1=CC=CC...
# 25251       20036  C[C@@H]1CC2=C(CN1C(=O)N1CCN(C)C[C@@H]1C1=CC=CC...
#
#                                              Target Name  \
# 0                      Cyclin-dependent kinase 7 [human]
# ...

# %%
reaxys_type_nan['lower_vals'] = lower_vals
reaxys_type_nan['upper_vals'] = upper_vals
# Out:
# /var/folders/7f/r6y7pww15x53z42m3h5vt12r0000gn/T/ipykernel_39654/1799842990.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reaxys_type_nan['lower_vals'] = lower_vals
# /var/folders/7f/r6y7pww15x53z42m3h5vt12r0000gn/T/ipykernel_39654/1799842990.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reaxys_type_nan['upper_vals'] = upper_vals

# %%
def transform(x):
    if x[0] in ['nM', 'nmol/l']:
        return x[1]
    elif x[0] in ['µM', 'μM', 'μmol/l']:
        return round(x[1] * 10**3, 1)
    elif x[0] == 'mM':
        return x[1] * 10**6
    elif x[0] == 'pM':
        return x[1] / 10**3
    elif x[0] in ['M', 'mol/l']:
        return x[1] * 10**9
    else:
        return None

# %%
chembl_type_nan['converted_value'] = chembl_type_nan[['Standard Units', 'Standard Value']].apply(lambda x: transform(x), axis = 1)
# Out:
# /var/folders/7f/r6y7pww15x53z42m3h5vt12r0000gn/T/ipykernel_39654/1971237900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chembl_type_nan['converted_value'] = chembl_type_nan[['Standard Units', 'Standard Value']].apply(lambda x: transform(x), axis = 1)

# %%
reaxys_type_nan['converted_value'] = reaxys_type_nan[['Unit', 'upper_vals']].apply(lambda x: transform(x), axis = 1)
# Out:
# /var/folders/7f/r6y7pww15x53z42m3h5vt12r0000gn/T/ipykernel_39654/3775283284.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reaxys_type_nan['converted_value'] = reaxys_type_nan[['Unit', 'upper_vals']].apply(lambda x: transform(x), axis = 1)

# %%
reaxys_pIC50 = reaxys_type_nan[reaxys_type_nan['Medchem: Measurement Parameter'] == 'pIC50']

# %%
IC50_vals = []

for value in reaxys_pIC50['upper_vals'].values:
    IC50 = 10**(9 - float(value))
    IC50_vals.append(IC50)
    
reaxys_pIC50['converted_value'] = IC50_vals
# Out:
# /var/folders/7f/r6y7pww15x53z42m3h5vt12r0000gn/T/ipykernel_39654/55384314.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reaxys_pIC50['converted_value'] = IC50_vals

# %%
reaxys_wout_pIC50 = reaxys_type_nan[reaxys_type_nan['Medchem: Measurement Parameter'] != 'pIC50']

# %%
reaxys_units_concat = pd.concat([reaxys_wout_pIC50, reaxys_pIC50], axis=0)

# %%
reaxys = reaxys_units_concat[['SMILES', 'converted_value']]

# %%
chembl = chembl_type_nan[['Smiles', 'converted_value']]

# %%
reaxys = reaxys.rename({'SMILES': 'smiles', 
                        'converted_value': 'value'}, axis=1)

chembl = chembl.rename({'Smiles': 'smiles', 
                        'converted_value': 'value'}, axis=1)

# %%
data = pd.concat([reaxys, chembl], axis=0)

# %% [markdown]
# # Классы
#
# События в блоке кода:
#
# - Добавление меток классов - если меньше или равно 20 нМ, то соединение можно считать активным

# %%
def set_class_activity(x):
    if x['value'] <= 20:
        return 1
    else:
        return 0

# %%
def set_class_label(x):
    if x['Activity_Flag'] == 'A':
        return 1
    else:
        return 0

# %%
data_excape = excape.assign(label = excape.apply(set_class_label, axis=1))
data_excape = data_excape[['SMILES', 'label']]
data_excape = data_excape.rename(columns={'SMILES': 'smiles'})

# %%
data = data.assign(label = data.apply(set_class_activity, axis=1))

# %%
data = pd.concat([data, data_excape], axis=0)

# %%
data['label'].value_counts()
# Out:
# 0    3603
# 1    1307
# Name: label, dtype: int64

# %%
data = data[['smiles', 'label']]

# %%
data.isna().sum()
# Out:
# smiles    46
# label      0
# dtype: int64

# %%
data = data[data['smiles'].notna()]

# %%
data.to_csv('data_basic_clean.csv')

# %% [markdown]
# # Молекулы
#
# События в блоке кода:
#
# - Восстанавление пропущенных значений по индексу Танимото
# - Отброс повторов молекул

# %%
chembl_nans = chembl_type[chembl_type['Standard Value'].isnull()]
chembl_nans_smiles = chembl_nans['Smiles'].to_list()

chembl_smiles = chembl['smiles'].to_list()

# %%
reaxys_nans = reaxys_type[reaxys_type['Quantitative value'].isnull()]
reaxys_nans_smiles = reaxys_nans['SMILES'].to_list()

reaxys_smiles = reaxys['smiles'].to_list()

# %%
researched_smiles = chembl_nans_smiles + reaxys_nans_smiles
reference_smiles = chembl_smiles + reaxys_smiles

# %%
researched_smiles = [x for x in researched_smiles if str(x) != 'nan']
reference_smiles = [x for x in reference_smiles if str(x) != 'nan']

# %%
researched_molecules = []

for smi in researched_smiles:
    mol = Chem.MolFromSmiles(smi)
    if mol is not None:
        researched_molecules.append(mol)

# %%
reference_molecules = []

for smi in reference_smiles:
    mol = Chem.MolFromSmiles(smi)
    if mol is not None:
        reference_molecules.append(mol)
# Out:
# [20:24:50] Explicit valence for atom # 0 N, 4, is greater than permitted
# [20:24:50] Explicit valence for atom # 0 N, 4, is greater than permitted
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# [20:24:50] WARNING: not removing hydrogen atom without neighbors
# ...

# %%
def tanimoto(reference_molecule, researched_molecule):

    fp = AllChem.GetMorganFingerprintAsBitVect(reference_molecule, 2, nBits = 1024)
    fp2 = AllChem.GetMorganFingerprintAsBitVect(researched_molecule, 2, nBits = 1024)

    same_parts = set(fp.GetOnBits()) & set(fp2.GetOnBits()) 
    different_parts = set(fp.GetOnBits()) | set(fp2.GetOnBits())
    
    return len(same_parts)/len(different_parts)

# %%
similarity = {}

for mol_res in researched_molecules:
    tanimoto_list = []
    for mol_ref in reference_molecules:
        sim = tanimoto(mol_ref, mol_res)
        tanimoto_list.append(sim)
    sim_max = max(tanimoto_list)
    mol_sim_max = reference_molecules[tanimoto_list.index(sim_max)]
    similarity[Chem.MolToSmiles(mol_res)] = [Chem.MolToSmiles(mol_sim_max), sim_max]

# %%
ref_smiles = []

for key in similarity:
    ref_smi = similarity[key][0]
    ref_smiles.append(ref_smi)

# %%
res_smiles = list(similarity.keys())

# %%
ref_labels = {}

for smi in ref_smiles:
    if smi in reference_smiles:
        label = data[data['smiles']==smi]['label'].values[0]
        ref_labels[smi] = label

# %%
ref_labels
# Out:
# {'Cc1ccc(C(=O)O)cc1S(=O)(=O)N(C)/N=C/c1cnn2ccc(Cl)nc12': 0,
#  'CN(/N=C/c1cnn2ccc(Cl)nc12)S(=O)(=O)c1ccc(F)cc1': 0,
#  'Cc1ccc(Br)cc1S(=O)(=O)N(C)/N=C/c1cnn2ccc(Cl)nc12': 0,
#  'Cc1ccc([N+](=O)[O-])cc1S(=O)(=O)N(C)/N=C/c1cnn2ccc(Cl)nc12': 0,
#  'Cc1ccn2ncc(/C=N/N(C)S(=O)(=O)c3cc([N+](=O)[O-])ccc3C)c2n1': 0,
#  'Cc1ccc([N+](=O)[O-])cc1S(=O)(=O)n1cc(-c2cnn3ccc(Cl)nc23)cn1': 0,
#  'Cc1cccc(S(=O)(=O)N(C)/N=C/c2cnn3ccc(Cl)nc23)c1': 0,
#  'Cc1ccc(C#N)cc1S(=O)(=O)N(C)CCc1cnn2ccc(Cl)nc12': 0,
#  'C=CC(=O)NCc1ccc(C(C)C(=O)Nc2cc(C3CC3)[nH]n2)cc1': 0,
#  'C=CC(=O)NCc1ccc(-c2ccc(C(C)C(=O)Nc3cc(C4CC4)[nH]n3)cn2)cn1': 0,
#  'C=CC(=O)NC(C)c1ccc(-c2ccc([C@H](C)C(=O)Nc3cc(C4CC4)[nH]n3)cc2)cn1': 0,
#  'CNS(=O)(=O)c1ccc(Nc2nc(N)c(/[N+]([O-])=N/C#N)c(OCC3CCCCC3)n2)cc1': 0,
#  'CC[C@H](CO)Nc1nc(NCc2ccccc2)n2ncc(C(C)C)c2n1': 0,
#  'CC[C@H](CO)Nc1nc(Nc2cccc(-c3ccccn3)c2)c2ncn(C(C)C)c2n1': 0,
#  'CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4': 0,
# ...

# %%
res_labels = [0] * len(res_smiles)

# %%
new_mols = dict(zip(res_smiles, res_labels))

# %%
new_mols_df = pd.DataFrame(list(new_mols.items()),
                      columns=['smiles','label'])

# %%
data = pd.concat([data, new_mols_df], axis=0)

# %%
data
# Out:
#                                                smiles  label
# 0   COC1=C2C(=O)C3=C(C(O)=C4C[C@](O)(C[C@H](O[C@H]...      0
# 1   COC1=C2C(=O)C3=C(C(O)=C4C[C@](O)(C[C@H](O[C@H]...      0
# 2   NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...      0
# 3   NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...      0
# 4   NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...      0
# ..                                                ...    ...
# 30  C[C@@H]1NC(=O)N[C@@H]1CCCCCC(=O)NCCCCCCCCC(=O)...      0
# 31  N#CCN(C(=O)CCOCCOCCNC(=O)COc1cccc2c1C(=O)N(C1C...      0
# 32  N#CCN(C(=O)CCOCCNC(=O)COc1cccc2c1C(=O)N(C1CCC(...      0
# 33  N#CCN(C(=O)CCNC(=O)COc1cccc2c1C(=O)N(C1CCC(=O)...      0
# 34  CC(C)n1cc(-c2ccnc3[nH]c(C4CCN(CC(=O)N(C)C)CC4)...      0
#
# [4899 rows x 2 columns]

# %%
data['smiles'].nunique()
# Out:
# 3490

# %%
df = data.drop_duplicates()

# %%
df
# Out:
#                                                smiles  label
# 0   COC1=C2C(=O)C3=C(C(O)=C4C[C@](O)(C[C@H](O[C@H]...      0
# 2   NC1=NC=NC2=C1N=CN2[C@@H]1O[C@H](COP(O)(=O)OP(O...      0
# 8              [NH3][Pt]1([NH3])OC(=O)C2(CCC2)C(=O)O1      0
# 11  [H][C@@]12C[C@H](O)[C@@]3(C)C(=O)[C@H](O)C4=C(...      0
# 13                                         [H].O.[Na]      0
# ..                                                ...    ...
# 30  C[C@@H]1NC(=O)N[C@@H]1CCCCCC(=O)NCCCCCCCCC(=O)...      0
# 31  N#CCN(C(=O)CCOCCOCCNC(=O)COc1cccc2c1C(=O)N(C1C...      0
# 32  N#CCN(C(=O)CCOCCNC(=O)COc1cccc2c1C(=O)N(C1CCC(...      0
# 33  N#CCN(C(=O)CCNC(=O)COc1cccc2c1C(=O)N(C1CCC(=O)...      0
# 34  CC(C)n1cc(-c2ccnc3[nH]c(C4CCN(CC(=O)N(C)C)CC4)...      0
#
# [3762 rows x 2 columns]

# %%
df.groupby(by='label').count()
# Out:
#        smiles
# label
# 0        2606
# 1        1156

# %% [markdown]
# # Сохранение
#
# События в блоке кода:
#
# - Формирование датасета
# - Сохранение в формате .csv

# %%
df.to_csv('data.csv')
